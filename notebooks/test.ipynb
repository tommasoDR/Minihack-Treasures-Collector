# %%
from src.explore_room import *

env = generate_env()

exhaustive_exploration(env.reset(), env)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 from src.explore_room import *
#       3 env = generate_env()
# ----> 5 exhaustive_exploration(env.reset(), env)
#
# File ~/Desktop/AIF-23-Project/src/explore_room.py:75, in exhaustive_exploration(initial_state, environment)
#      72     new_state, _, _, _ = environment.step(action)
#      74     image.set_data(new_state['pixel'][:, 410:840])
# ---> 75     display.display(plt.gcf())
#      76     display.clear_output(wait=True)
#      78 # next loop I'll start from where I arrived
#
# File ~/anaconda3/envs/nle/lib/python3.8/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# ...
