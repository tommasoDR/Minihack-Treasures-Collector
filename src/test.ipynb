# %%
from explore_room import *

env = generate_env()

exhaustive_exploration(env.reset(), env)
# Out:
#
#
#                             {{{{{{{{{{{{{{{{{{{{{{{
#                            {-----------------------{
#                            {|{{{{{{{{{{{{{{{{{{{{{|{
#                            {|{...................{|{
#                            {|{...%...............{|{
#                            {|{...................{|{
#                            {|{...................{|{
#                            {|{.......$...........{|{
#                            {|{...................{|{
#                            {|{...(....=..........{|{
#                            {|{...................{|{
#                            {|{.........*.......?.{|{
#                            {|{....?............?.{|{
#                            {|{...................{|{
#                            {|{.*.................{|{
#                            {|{.............%.....{|{
#                            {|{{{{{{{{{{{{{{{{{{{{{|{
#                            {-----------------------{
#
#
#
# ...
